# %%
import re
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from natsort import natsorted

sns.set_context("talk")

# %%
METRICS_CSV = Path("/Users/danie/repos/alpaca-segmentation/data_postprocessing/BENCHMARK/metrics.csv")  # adjust if saved elsewhere
assert METRICS_CSV.exists(), f"{METRICS_CSV} not found"

# %%
# Load the metrics CSV
df = pd.read_csv(METRICS_CSV)

df = df.set_index(["model", "variant"])
df = df.loc[natsorted(df.index)].reset_index()

def parse_variant_tag(tag: str):
    """return seq_len (ms), hop (ms), threshold (float)"""
    m = re.match(r"len(\d+)_hop(\d+)_th(\d+)", tag)
    if not m:
        return None, None, None
    seq = int(m[1]) / 1000  # back to s
    hop = int(m[2]) / 1000
    th = int(m[3]) / 100
    return seq, hop, th

df[["seq_len_s", "hop_s", "threshold"]] = (
    df["variant"].apply(lambda t: pd.Series(parse_variant_tag(t)))
)

# %%
leader_cols = [
    "model",
    "variant",
    "precision",
    "recall",
    "f1",
    "mean_dstart_ms",
    "mean_dend_ms",
]
leader = df[leader_cols].sort_values("f1", ascending=False)
leader.head(50)
# Out:
#                            model             variant  precision    recall  \
# 26  v3_clipwise_balanced_nph_1.5  len400_hop050_th90   0.058531  0.519337
# 35    v4_clipwise_balanced_nph_2  len400_hop050_th90   0.037743  0.569061
# 25  v3_clipwise_balanced_nph_1.5  len400_hop050_th80   0.027070  0.469613
# 24  v3_clipwise_balanced_nph_1.5  len400_hop050_th70   0.018549  0.436464
# 34    v4_clipwise_balanced_nph_2  len400_hop050_th80   0.017794  0.580110
# 17    v2_clipwise_balanced_nph_1  len400_hop050_th90   0.014871  0.563536
# 23  v3_clipwise_balanced_nph_1.5  len400_hop050_th60   0.014093  0.408840
# 33    v4_clipwise_balanced_nph_2  len400_hop050_th70   0.012671  0.569061
# 16    v2_clipwise_balanced_nph_1  len400_hop050_th80   0.011255  0.486188
# 22  v3_clipwise_balanced_nph_1.5  len400_hop050_th50   0.011174  0.381215
# 32    v4_clipwise_balanced_nph_2  len400_hop050_th60   0.010148  0.546961
# 15    v2_clipwise_balanced_nph_1  len400_hop050_th70   0.009644  0.453039
# 21  v3_clipwise_balanced_nph_1.5  len400_hop050_th40   0.009377  0.359116
# 14    v2_clipwise_balanced_nph_1  len400_hop050_th60   0.008610  0.436464
# 31    v4_clipwise_balanced_nph_2  len400_hop050_th50   0.008008  0.480663
# 20  v3_clipwise_balanced_nph_1.5  len400_hop050_th30   0.007893  0.331492
# 13    v2_clipwise_balanced_nph_1  len400_hop050_th50   0.007577  0.403315
# 8   v1_clipwise_balanced_nph_0.5  len400_hop050_th90   0.007259  0.370166
# 19  v3_clipwise_balanced_nph_1.5  len400_hop050_th20   0.006834  0.314917
# 12    v2_clipwise_balanced_nph_1  len400_hop050_th40   0.006305  0.353591
# 30    v4_clipwise_balanced_nph_2  len400_hop050_th40   0.006070  0.392265
# 7   v1_clipwise_balanced_nph_0.5  len400_hop050_th80   0.005561  0.314917
# 18  v3_clipwise_balanced_nph_1.5  len400_hop050_th10   0.005526  0.281768
# 11    v2_clipwise_balanced_nph_1  len400_hop050_th30   0.005301  0.314917
# 29    v4_clipwise_balanced_nph_2  len400_hop050_th30   0.004714  0.320442
# 6   v1_clipwise_balanced_nph_0.5  len400_hop050_th70   0.004631  0.281768
# 10    v2_clipwise_balanced_nph_1  len400_hop050_th20   0.004196  0.265193
# 5   v1_clipwise_balanced_nph_0.5  len400_hop050_th60   0.004075  0.259669
# 4   v1_clipwise_balanced_nph_0.5  len400_hop050_th50   0.003626  0.237569
# 28    v4_clipwise_balanced_nph_2  len400_hop050_th20   0.003465  0.248619
# 3   v1_clipwise_balanced_nph_0.5  len400_hop050_th40   0.003259  0.220994
# 2   v1_clipwise_balanced_nph_0.5  len400_hop050_th30   0.002964  0.204420
# 9     v2_clipwise_balanced_nph_1  len400_hop050_th10   0.002828  0.193370
# 1   v1_clipwise_balanced_nph_0.5  len400_hop050_th20   0.002757  0.193370
# 27    v4_clipwise_balanced_nph_2  len400_hop050_th10   0.002742  0.204420
# 0   v1_clipwise_balanced_nph_0.5  len400_hop050_th10   0.002151  0.154696
#
#           f1  mean_dstart_ms  mean_dend_ms
# 26  0.105204      207.170213    177.372340
# 35  0.070790      112.640777     81.611650
# 25  0.051189      218.400000    203.529412
# 24  0.035586      228.987342    217.607595
# 34  0.034528      150.952381    103.914286
# 17  0.028977      201.627451    121.176471
# 23  0.027246      253.324324    223.202703
# 33  0.024789      174.825243    128.349515
# 16  0.022000      235.159091    158.113636
# 22  0.021712      233.405797    225.782609
# 32  0.019926      202.767677    155.757576
# 15  0.018885      236.963415    172.939024
# 21  0.018276      246.169231    231.476923
# 14  0.016888      246.000000    176.518987
# 31  0.015754      218.758621    177.942529
# 20  0.015418      248.600000    229.550000
# 13  0.014875      254.561644    191.534247
# 8   0.014239      260.089552    184.761194
# 19  0.013377      248.228070    261.263158
# 12  0.012389      265.031250    219.093750
# 30  0.011956      241.014085    221.098592
# 7   0.010929      271.649123    241.087719
# 18  0.010840      254.235294    267.509804
# 11  0.010427      265.526316    242.157895
# 29  0.009290      256.775862    251.362069
# 6   0.009112      275.411765    263.960784
# 10  0.008262      272.812500    226.312500
# 5   0.008024      283.276596    285.914894
# 4   0.007143      286.883721    286.046512
# 28  0.006834      276.600000    255.333333
# 3   0.006424      284.925000    296.750000
# 2   0.005842      289.891892    305.729730
# 9   0.005574      287.342857    244.200000
# 1   0.005437      278.885714    312.057143
# 27  0.005412      294.567568    293.783784
# 0   0.004244      326.892857    348.000000

# %%
filtered_df = df[df["variant"].str.endswith(("_th70", "_th80", "_th90"))]
filtered_leader = filtered_df[leader_cols].sort_values("recall", ascending=False)
filtered_leader.head(50)
# Out:
#                            model             variant  precision    recall  \
# 34    v4_clipwise_balanced_nph_2  len400_hop050_th80   0.017794  0.580110
# 33    v4_clipwise_balanced_nph_2  len400_hop050_th70   0.012671  0.569061
# 35    v4_clipwise_balanced_nph_2  len400_hop050_th90   0.037743  0.569061
# 17    v2_clipwise_balanced_nph_1  len400_hop050_th90   0.014871  0.563536
# 26  v3_clipwise_balanced_nph_1.5  len400_hop050_th90   0.058531  0.519337
# 16    v2_clipwise_balanced_nph_1  len400_hop050_th80   0.011255  0.486188
# 25  v3_clipwise_balanced_nph_1.5  len400_hop050_th80   0.027070  0.469613
# 15    v2_clipwise_balanced_nph_1  len400_hop050_th70   0.009644  0.453039
# 24  v3_clipwise_balanced_nph_1.5  len400_hop050_th70   0.018549  0.436464
# 8   v1_clipwise_balanced_nph_0.5  len400_hop050_th90   0.007259  0.370166
# 7   v1_clipwise_balanced_nph_0.5  len400_hop050_th80   0.005561  0.314917
# 6   v1_clipwise_balanced_nph_0.5  len400_hop050_th70   0.004631  0.281768
#
#           f1  mean_dstart_ms  mean_dend_ms
# 34  0.034528      150.952381    103.914286
# 33  0.024789      174.825243    128.349515
# 35  0.070790      112.640777     81.611650
# 17  0.028977      201.627451    121.176471
# 26  0.105204      207.170213    177.372340
# 16  0.022000      235.159091    158.113636
# 25  0.051189      218.400000    203.529412
# 15  0.018885      236.963415    172.939024
# 24  0.035586      228.987342    217.607595
# 8   0.014239      260.089552    184.761194
# 7   0.010929      271.649123    241.087719
# 6   0.009112      275.411765    263.960784

# %% [markdown]
# ### Recall vs. threshold for each model

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["recall"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("Recall")
plt.title("Recall over threshold")
plt.legend()
plt.grid(True)
plt.show()

# %%
df_th90 = df[df["threshold"] == 0.9]

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_th90["model"], df_th90["recall"])
plt.xlabel("Model")
plt.ylabel("Recall")
plt.title("Recall at Threshold = 0.9")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df_th90["model"], df_th90["recall_q1"], color="teal")
plt.title("Recall Q1 at Threshold = 0.9")
plt.xlabel("Model")
plt.ylabel("Recall (Q1)")
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ## Recall vs. threshold for each quality (Q1–Q3)

# %%
qualities = ["recall_q1", "recall_q2", "recall_q3"]

for q in qualities:
    if q in df.columns:
        plt.figure(figsize=(10, 5))
        for model, sub in df.groupby("model"):
            sub_sorted = sub.sort_values("threshold")
            plt.plot(
                sub_sorted["threshold"],
                sub_sorted[q],
                marker="o",
                label=model
            )
        plt.title(f"Recall across thresholds – {q.upper()}")
        plt.xlabel("threshold")
        plt.ylabel("Recall")
        plt.ylim(0, 1)
        plt.grid(True)
        plt.legend(title="Model")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Detected calls vs. threshold (log scale)

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["n_pred"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("# detected calls (log)")
plt.yscale("log")
plt.title("Call count vs. threshold")
plt.legend()
plt.grid(True, which="both", axis="y", linestyle=":")
plt.show()

# %% [markdown]
# ### Top‑5 variants by F1

# %%
leader.head(5).style.format({"precision": "{:.2%}", "recall": "{:.2%}", "f1": "{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a53b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a53b_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_6a53b_level0_col1" class="col_heading level0 col1" >variant</th>
#       <th id="T_6a53b_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_6a53b_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_6a53b_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_6a53b_level0_col5" class="col_heading level0 col5" >mean_dstart_ms</th>
#       <th id="T_6a53b_level0_col6" class="col_heading level0 col6" >mean_dend_ms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a53b_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_6a53b_row0_col0" class="data row0 col0" >v3_clipwise_balanced_nph_1.5</td>
#       <td id="T_6a53b_row0_col1" class="data row0 col1" >len400_hop050_th90</td>
#       <td id="T_6a53b_row0_col2" class="data row0 col2" >5.85%</td>
#       <td id="T_6a53b_row0_col3" class="data row0 col3" >51.93%</td>
#       <td id="T_6a53b_row0_col4" class="data row0 col4" >10.52%</td>
#       <td id="T_6a53b_row0_col5" class="data row0 col5" >207.170213</td>
#       <td id="T_6a53b_row0_col6" class="data row0 col6" >177.372340</td>
#     </tr>
#     <tr>
#       <th id="T_6a53b_level0_row1" class="row_heading level0 row1" >35</th>
#       <td id="T_6a53b_row1_col0" class="data row1 col0" >v4_clipwise_balanced_nph_2</td>
#       <td id="T_6a53b_row1_col1" class="data row1 col1" >len400_hop050_th90</td>
#       <td id="T_6a53b_row1_col2" class="data row1 col2" >3.77%</td>
#       <td id="T_6a53b_row1_col3" class="data row1 col3" >56.91%</td>
#       <td id="T_6a53b_row1_col4" class="data row1 col4" >7.08%</td>
#       <td id="T_6a53b_row1_col5" class="data row1 col5" >112.640777</td>
#       <td id="T_6a53b_row1_col6" class="data row1 col6" >81.611650</td>
#     </tr>
#     <tr>
#       <th id="T_6a53b_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_6a53b_row2_col0" class="data row2 col0" >v3_clipwise_balanced_nph_1.5</td>
#       <td id="T_6a53b_row2_col1" class="data row2 col1" >len400_hop050_th80</td>
#       <td id="T_6a53b_row2_col2" class="data row2 col2" >2.71%</td>
#       <td id="T_6a53b_row2_col3" class="data row2 col3" >46.96%</td>
#       <td id="T_6a53b_row2_col4" class="data row2 col4" >5.12%</td>
#       <td id="T_6a53b_row2_col5" class="data row2 col5" >218.400000</td>
#       <td id="T_6a53b_row2_col6" class="data row2 col6" >203.529412</td>
#     </tr>
#     <tr>
#       <th id="T_6a53b_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_6a53b_row3_col0" class="data row3 col0" >v3_clipwise_balanced_nph_1.5</td>
#       <td id="T_6a53b_row3_col1" class="data row3 col1" >len400_hop050_th70</td>
#       <td id="T_6a53b_row3_col2" class="data row3 col2" >1.85%</td>
#       <td id="T_6a53b_row3_col3" class="data row3 col3" >43.65%</td>
#       <td id="T_6a53b_row3_col4" class="data row3 col4" >3.56%</td>
#       <td id="T_6a53b_row3_col5" class="data row3 col5" >228.987342</td>
#       <td id="T_6a53b_row3_col6" class="data row3 col6" >217.607595</td>
#     </tr>
#     <tr>
#       <th id="T_6a53b_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_6a53b_row4_col0" class="data row4 col0" >v4_clipwise_balanced_nph_2</td>
#       <td id="T_6a53b_row4_col1" class="data row4 col1" >len400_hop050_th80</td>
#       <td id="T_6a53b_row4_col2" class="data row4 col2" >1.78%</td>
#       <td id="T_6a53b_row4_col3" class="data row4 col3" >58.01%</td>
#       <td id="T_6a53b_row4_col4" class="data row4 col4" >3.45%</td>
#       <td id="T_6a53b_row4_col5" class="data row4 col5" >150.952381</td>
#       <td id="T_6a53b_row4_col6" class="data row4 col6" >103.914286</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### F1 vs. threshold curve for each model

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["f1"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("F1")
plt.title("F1 over classification threshold")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Boundary error distributions

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Automatically get unique model names in the order they appear
model_order = df["model"].unique()

# Generate a color palette with as many colors as there are models
custom_palette = sns.color_palette("tab10", n_colors=len(model_order))
palette_dict = dict(zip(model_order, custom_palette))

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(
    x="model",
    y="mean_dstart_ms",
    data=df,
    ax=axs[0],
    palette=palette_dict,
    order=model_order
)
axs[0].set_title("|Δstart| (ms)")
axs[0].set_ylabel("mean absolute error (ms)")
axs[0].tick_params(axis='x', rotation=45)

sns.boxplot(
    x="model",
    y="mean_dend_ms",
    data=df,
    ax=axs[1],
    palette=palette_dict,
    order=model_order
)
axs[1].set_title("|Δend| (ms)")
axs[1].set_ylabel("mean absolute error (ms)")
axs[1].tick_params(axis='x', rotation=45)

#plt.tight_layout()
plt.show()
# Out:
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_55141/2382098644.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_55141/2382098644.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
