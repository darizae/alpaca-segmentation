# %%
import re
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from natsort import natsorted

sns.set_context("talk")

# %%
METRICS_CSV = Path("/Users/danie/repos/alpaca-segmentation/data_postprocessing/BENCHMARK_01/metrics_rf.csv")  # adjust if saved elsewhere
assert METRICS_CSV.exists(), f"{METRICS_CSV} not found"

# %%
# Load the metrics CSV
df = pd.read_csv(METRICS_CSV)

df = df.set_index(["model", "variant"])
df = df.loc[natsorted(df.index)].reset_index()

def parse_variant_tag(tag: str):
    """return seq_len (ms), hop (ms), threshold (float)"""
    m = re.match(r"len(\d+)_hop(\d+)_th(\d+)", tag)
    if not m:
        return None, None, None
    seq = int(m[1]) / 1000  # back to s
    hop = int(m[2]) / 1000
    th = int(m[3]) / 100
    return seq, hop, th

df[["seq_len_s", "hop_s", "threshold"]] = (
    df["variant"].apply(lambda t: pd.Series(parse_variant_tag(t)))
)

# %%
leader_cols = [
    "model",
    "variant",
    "precision",
    "recall",
    "f1",
    "mean_dstart_ms",
    "mean_dend_ms",
]
leader = df[leader_cols].sort_values("f1", ascending=False)
leader.head(50)
# Out:
#                                      model             variant  precision  \
# 8               v1_clipwise_balanced_nph_1  len400_hop050_th90   0.325758
# 26               v3_quality_balanced_nph_1  len400_hop050_th90   0.292035
# 7               v1_clipwise_balanced_nph_1  len400_hop050_th80   0.248428
# 6               v1_clipwise_balanced_nph_1  len400_hop050_th70   0.209366
# 25               v3_quality_balanced_nph_1  len400_hop050_th80   0.229839
# 5               v1_clipwise_balanced_nph_1  len400_hop050_th60   0.182957
# 35                         v4_random_nph_1  len400_hop050_th90   0.191275
# 17  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th90   0.187291
# 24               v3_quality_balanced_nph_1  len400_hop050_th70   0.194030
# 4               v1_clipwise_balanced_nph_1  len400_hop050_th50   0.164286
# 23               v3_quality_balanced_nph_1  len400_hop050_th60   0.175258
# 3               v1_clipwise_balanced_nph_1  len400_hop050_th40   0.135667
# 22               v3_quality_balanced_nph_1  len400_hop050_th50   0.153355
# 21               v3_quality_balanced_nph_1  len400_hop050_th40   0.137427
# 16  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th80   0.130548
# 34                         v4_random_nph_1  len400_hop050_th80   0.130556
# 20               v3_quality_balanced_nph_1  len400_hop050_th30   0.123656
# 2               v1_clipwise_balanced_nph_1  len400_hop050_th30   0.108911
# 15  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th70   0.099783
# 33                         v4_random_nph_1  len400_hop050_th70   0.095465
# 1               v1_clipwise_balanced_nph_1  len400_hop050_th20   0.084532
# 19               v3_quality_balanced_nph_1  len400_hop050_th20   0.089806
# 14  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th60   0.081285
# 32                         v4_random_nph_1  len400_hop050_th60   0.075431
# 13  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th50   0.067826
# 31                         v4_random_nph_1  len400_hop050_th50   0.063265
# 18               v3_quality_balanced_nph_1  len400_hop050_th10   0.063291
# 0               v1_clipwise_balanced_nph_1  len400_hop050_th10   0.056314
# 12  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th40   0.050847
# 30                         v4_random_nph_1  len400_hop050_th40   0.051081
# 11  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th30   0.038849
# 29                         v4_random_nph_1  len400_hop050_th30   0.038113
# 28                         v4_random_nph_1  len400_hop050_th20   0.030822
# 10  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th20   0.027451
# 9   v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th10   0.024970
# 27                         v4_random_nph_1  len400_hop050_th10   0.019578
#
#       recall        f1  mean_dstart_ms  mean_dend_ms
# 8   0.475138  0.386517      200.337209    115.337209
# 26  0.364641  0.324324      232.181818    189.151515
# 7   0.436464  0.316633      226.405063    130.658228
# 6   0.419890  0.279412      238.460526    143.539474
# 25  0.314917  0.265734      243.403509    216.403509
# 5   0.403315  0.251724      247.616438    146.890411
# 35  0.314917  0.237996      241.421053    223.807018
# 17  0.309392  0.233333      238.803571    238.839286
# 24  0.287293  0.231626      251.038462    224.750000
# 4   0.381215  0.229617      257.086957    157.855072
# 23  0.281768  0.216102      256.333333    226.490196
# 3   0.342541  0.194357      264.822581    180.564516
# 22  0.265193  0.194332      260.750000    228.708333
# 21  0.259669  0.179732      264.829787    231.872340
# 16  0.276243  0.177305      254.660000    250.060000
# 34  0.259669  0.173752      255.191489    242.723404
# 20  0.254144  0.166365      278.717391    232.304348
# 2   0.303867  0.160350      265.309091    199.563636
# 15  0.254144  0.143302      257.543478    259.739130
# 33  0.220994  0.133333      301.325000    247.425000
# 1   0.259669  0.127544      272.510638    226.170213
# 19  0.204420  0.124789      275.594595    243.972973
# 14  0.237569  0.121127      257.302326    264.790698
# 32  0.193370  0.108527      298.371429    257.228571
# 13  0.215470  0.103175      261.128205    264.538462
# 31  0.171271  0.092399      310.096774    271.354839
# 18  0.165746  0.091603      281.533333    249.533333
# 0   0.182320  0.086050      288.393939    232.696970
# 12  0.182320  0.079518      269.030303    266.090909
# 30  0.143646  0.075362      321.730769    267.769231
# 11  0.149171  0.061644      281.518519    278.629630
# 29  0.116022  0.057377      335.809524    278.428571
# 28  0.099448  0.047059      345.833333    291.666667
# 10  0.116022  0.044397      317.857143    283.142857
# 9   0.116022  0.041096      336.904762    297.428571
# 27  0.071823  0.030769      362.076923    313.153846

# %%
filtered_df = df[df["variant"].str.endswith(("_th70", "_th80", "_th90"))]
filtered_leader = filtered_df[leader_cols].sort_values("recall", ascending=False)
filtered_leader.head(50)
# Out:
#                                      model             variant  precision  \
# 8               v1_clipwise_balanced_nph_1  len400_hop050_th90   0.325758
# 7               v1_clipwise_balanced_nph_1  len400_hop050_th80   0.248428
# 6               v1_clipwise_balanced_nph_1  len400_hop050_th70   0.209366
# 26               v3_quality_balanced_nph_1  len400_hop050_th90   0.292035
# 25               v3_quality_balanced_nph_1  len400_hop050_th80   0.229839
# 35                         v4_random_nph_1  len400_hop050_th90   0.191275
# 17  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th90   0.187291
# 24               v3_quality_balanced_nph_1  len400_hop050_th70   0.194030
# 16  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th80   0.130548
# 34                         v4_random_nph_1  len400_hop050_th80   0.130556
# 15  v2_quality_and_clipwise_balanced_nph_1  len400_hop050_th70   0.099783
# 33                         v4_random_nph_1  len400_hop050_th70   0.095465
#
#       recall        f1  mean_dstart_ms  mean_dend_ms
# 8   0.475138  0.386517      200.337209    115.337209
# 7   0.436464  0.316633      226.405063    130.658228
# 6   0.419890  0.279412      238.460526    143.539474
# 26  0.364641  0.324324      232.181818    189.151515
# 25  0.314917  0.265734      243.403509    216.403509
# 35  0.314917  0.237996      241.421053    223.807018
# 17  0.309392  0.233333      238.803571    238.839286
# 24  0.287293  0.231626      251.038462    224.750000
# 16  0.276243  0.177305      254.660000    250.060000
# 34  0.259669  0.173752      255.191489    242.723404
# 15  0.254144  0.143302      257.543478    259.739130
# 33  0.220994  0.133333      301.325000    247.425000

# %% [markdown]
# ### Recall vs. threshold for each model

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["recall"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("Recall")
plt.title("Recall over threshold")
plt.legend()
plt.grid(True)
plt.show()

# %%
df_th90 = df[df["threshold"] == 0.9]

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_th90["model"], df_th90["recall"])
plt.xlabel("Model")
plt.ylabel("Recall")
plt.title("Recall at Threshold = 0.9")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df_th90["model"], df_th90["recall_q1"], color="teal")
plt.title("Recall Q1 at Threshold = 0.9")
plt.xlabel("Model")
plt.ylabel("Recall (Q1)")
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ## Recall vs. threshold for each quality (Q1–Q3)

# %%
qualities = ["recall_q1", "recall_q2", "recall_q3"]

for q in qualities:
    if q in df.columns:
        plt.figure(figsize=(10, 5))
        for model, sub in df.groupby("model"):
            sub_sorted = sub.sort_values("threshold")
            plt.plot(
                sub_sorted["threshold"],
                sub_sorted[q],
                marker="o",
                label=model
            )
        plt.title(f"Recall across thresholds – {q.upper()}")
        plt.xlabel("threshold")
        plt.ylabel("Recall")
        plt.ylim(0, 1)
        plt.grid(True)
        plt.legend(title="Model")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Detected calls vs. threshold (log scale)

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["n_pred"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("# detected calls (log)")
plt.yscale("log")
plt.title("Call count vs. threshold")
plt.legend()
plt.grid(True, which="both", axis="y", linestyle=":")
plt.show()

# %% [markdown]
# ### Top‑5 variants by F1

# %%
leader.head(5).style.format({"precision": "{:.2%}", "recall": "{:.2%}", "f1": "{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4840b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4840b_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_4840b_level0_col1" class="col_heading level0 col1" >variant</th>
#       <th id="T_4840b_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_4840b_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_4840b_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_4840b_level0_col5" class="col_heading level0 col5" >mean_dstart_ms</th>
#       <th id="T_4840b_level0_col6" class="col_heading level0 col6" >mean_dend_ms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4840b_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_4840b_row0_col0" class="data row0 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_4840b_row0_col1" class="data row0 col1" >len400_hop050_th90</td>
#       <td id="T_4840b_row0_col2" class="data row0 col2" >32.58%</td>
#       <td id="T_4840b_row0_col3" class="data row0 col3" >47.51%</td>
#       <td id="T_4840b_row0_col4" class="data row0 col4" >38.65%</td>
#       <td id="T_4840b_row0_col5" class="data row0 col5" >200.337209</td>
#       <td id="T_4840b_row0_col6" class="data row0 col6" >115.337209</td>
#     </tr>
#     <tr>
#       <th id="T_4840b_level0_row1" class="row_heading level0 row1" >26</th>
#       <td id="T_4840b_row1_col0" class="data row1 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_4840b_row1_col1" class="data row1 col1" >len400_hop050_th90</td>
#       <td id="T_4840b_row1_col2" class="data row1 col2" >29.20%</td>
#       <td id="T_4840b_row1_col3" class="data row1 col3" >36.46%</td>
#       <td id="T_4840b_row1_col4" class="data row1 col4" >32.43%</td>
#       <td id="T_4840b_row1_col5" class="data row1 col5" >232.181818</td>
#       <td id="T_4840b_row1_col6" class="data row1 col6" >189.151515</td>
#     </tr>
#     <tr>
#       <th id="T_4840b_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_4840b_row2_col0" class="data row2 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_4840b_row2_col1" class="data row2 col1" >len400_hop050_th80</td>
#       <td id="T_4840b_row2_col2" class="data row2 col2" >24.84%</td>
#       <td id="T_4840b_row2_col3" class="data row2 col3" >43.65%</td>
#       <td id="T_4840b_row2_col4" class="data row2 col4" >31.66%</td>
#       <td id="T_4840b_row2_col5" class="data row2 col5" >226.405063</td>
#       <td id="T_4840b_row2_col6" class="data row2 col6" >130.658228</td>
#     </tr>
#     <tr>
#       <th id="T_4840b_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_4840b_row3_col0" class="data row3 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_4840b_row3_col1" class="data row3 col1" >len400_hop050_th70</td>
#       <td id="T_4840b_row3_col2" class="data row3 col2" >20.94%</td>
#       <td id="T_4840b_row3_col3" class="data row3 col3" >41.99%</td>
#       <td id="T_4840b_row3_col4" class="data row3 col4" >27.94%</td>
#       <td id="T_4840b_row3_col5" class="data row3 col5" >238.460526</td>
#       <td id="T_4840b_row3_col6" class="data row3 col6" >143.539474</td>
#     </tr>
#     <tr>
#       <th id="T_4840b_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_4840b_row4_col0" class="data row4 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_4840b_row4_col1" class="data row4 col1" >len400_hop050_th80</td>
#       <td id="T_4840b_row4_col2" class="data row4 col2" >22.98%</td>
#       <td id="T_4840b_row4_col3" class="data row4 col3" >31.49%</td>
#       <td id="T_4840b_row4_col4" class="data row4 col4" >26.57%</td>
#       <td id="T_4840b_row4_col5" class="data row4 col5" >243.403509</td>
#       <td id="T_4840b_row4_col6" class="data row4 col6" >216.403509</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### F1 vs. threshold curve for each model

# %%
plt.figure(figsize=(10, 6))
for model, sub in df.groupby("model"):
    sub_sorted = sub.sort_values("threshold")
    plt.plot(sub_sorted["threshold"], sub_sorted["f1"], "-o", label=model)
plt.xlabel("threshold")
plt.ylabel("F1")
plt.title("F1 over classification threshold")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Boundary error distributions

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Automatically get unique model names in the order they appear
model_order = df["model"].unique()

# Generate a color palette with as many colors as there are models
custom_palette = sns.color_palette("tab10", n_colors=len(model_order))
palette_dict = dict(zip(model_order, custom_palette))

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(
    x="model",
    y="mean_dstart_ms",
    data=df,
    ax=axs[0],
    palette=palette_dict,
    order=model_order
)
axs[0].set_title("|Δstart| (ms)")
axs[0].set_ylabel("mean absolute error (ms)")
axs[0].tick_params(axis='x', rotation=45)

sns.boxplot(
    x="model",
    y="mean_dend_ms",
    data=df,
    ax=axs[1],
    palette=palette_dict,
    order=model_order
)
axs[1].set_title("|Δend| (ms)")
axs[1].set_ylabel("mean absolute error (ms)")
axs[1].tick_params(axis='x', rotation=45)

#plt.tight_layout()
plt.show()
# Out:
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_57594/2382098644.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_57594/2382098644.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# ---- helpers for convenience ----
def leaderboard(metric: str, top=50, df_=None):
    """Return a compact leaderboard sorted by the chosen metric."""
    if df_ is None:
        df_ = df
    cols = [
        "model", "variant", "layer",
        "precision", "recall", "f1",
        "mean_dstart_ms", "mean_dend_ms",
    ]
    have = [c for c in cols if c in df_.columns]
    return df_[have].sort_values(metric, ascending=False).head(top)

def _line_per_model_or_layer(ax, subdf, y, title, share_ylim=(0,1)):
    """Lineplot over threshold for each (model, layer)."""
    group_keys = ["model", "layer"] if "layer" in subdf.columns else ["model"]
    for key, g in subdf.groupby(group_keys):
        label = " • ".join(key) if isinstance(key, tuple) else key
        g = g.sort_values("threshold")
        ax.plot(g["threshold"], g[y], "-o", label=label)
    ax.set_title(title)
    ax.set_xlabel("threshold")
    ax.set_ylabel(y.capitalize())
    if share_ylim:
        ax.set_ylim(*share_ylim)
    ax.grid(True)

def _bar_by_model(ax, subdf, y, title):
    """Bar chart for one metric for each model (and layer if present)."""
    xlab = "model"
    if "layer" in subdf.columns:
        subdf = subdf.copy()
        subdf[xlab] = subdf["model"].astype(str) + " (" + subdf["layer"].astype(str) + ")"
    ax.bar(subdf[xlab], subdf[y])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(y.capitalize())
    ax.set_xticks(range(len(subdf)))
    ax.set_xticklabels(subdf[xlab], rotation=45, ha="right")
    ax.grid(axis="y")

# %%
# Top-k by each metric
leader_precision = leaderboard("precision", top=50)
leader_recall    = leaderboard("recall",    top=50)
leader_f1        = leaderboard("f1",        top=50)

leader_precision.style.format({"precision": "{:.2%}", "recall": "{:.2%}", "f1": "{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_519c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_519c6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_519c6_level0_col1" class="col_heading level0 col1" >variant</th>
#       <th id="T_519c6_level0_col2" class="col_heading level0 col2" >layer</th>
#       <th id="T_519c6_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_519c6_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_519c6_level0_col5" class="col_heading level0 col5" >f1</th>
#       <th id="T_519c6_level0_col6" class="col_heading level0 col6" >mean_dstart_ms</th>
#       <th id="T_519c6_level0_col7" class="col_heading level0 col7" >mean_dend_ms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_519c6_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_519c6_row0_col0" class="data row0 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row0_col1" class="data row0 col1" >len400_hop050_th90</td>
#       <td id="T_519c6_row0_col2" class="data row0 col2" >postrf</td>
#       <td id="T_519c6_row0_col3" class="data row0 col3" >32.58%</td>
#       <td id="T_519c6_row0_col4" class="data row0 col4" >47.51%</td>
#       <td id="T_519c6_row0_col5" class="data row0 col5" >38.65%</td>
#       <td id="T_519c6_row0_col6" class="data row0 col6" >200.337209</td>
#       <td id="T_519c6_row0_col7" class="data row0 col7" >115.337209</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row1" class="row_heading level0 row1" >26</th>
#       <td id="T_519c6_row1_col0" class="data row1 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_519c6_row1_col1" class="data row1 col1" >len400_hop050_th90</td>
#       <td id="T_519c6_row1_col2" class="data row1 col2" >postrf</td>
#       <td id="T_519c6_row1_col3" class="data row1 col3" >29.20%</td>
#       <td id="T_519c6_row1_col4" class="data row1 col4" >36.46%</td>
#       <td id="T_519c6_row1_col5" class="data row1 col5" >32.43%</td>
#       <td id="T_519c6_row1_col6" class="data row1 col6" >232.181818</td>
#       <td id="T_519c6_row1_col7" class="data row1 col7" >189.151515</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_519c6_row2_col0" class="data row2 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row2_col1" class="data row2 col1" >len400_hop050_th80</td>
#       <td id="T_519c6_row2_col2" class="data row2 col2" >postrf</td>
#       <td id="T_519c6_row2_col3" class="data row2 col3" >24.84%</td>
#       <td id="T_519c6_row2_col4" class="data row2 col4" >43.65%</td>
#       <td id="T_519c6_row2_col5" class="data row2 col5" >31.66%</td>
#       <td id="T_519c6_row2_col6" class="data row2 col6" >226.405063</td>
#       <td id="T_519c6_row2_col7" class="data row2 col7" >130.658228</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row3" class="row_heading level0 row3" >25</th>
#       <td id="T_519c6_row3_col0" class="data row3 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_519c6_row3_col1" class="data row3 col1" >len400_hop050_th80</td>
#       <td id="T_519c6_row3_col2" class="data row3 col2" >postrf</td>
#       <td id="T_519c6_row3_col3" class="data row3 col3" >22.98%</td>
#       <td id="T_519c6_row3_col4" class="data row3 col4" >31.49%</td>
#       <td id="T_519c6_row3_col5" class="data row3 col5" >26.57%</td>
#       <td id="T_519c6_row3_col6" class="data row3 col6" >243.403509</td>
#       <td id="T_519c6_row3_col7" class="data row3 col7" >216.403509</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_519c6_row4_col0" class="data row4 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row4_col1" class="data row4 col1" >len400_hop050_th70</td>
#       <td id="T_519c6_row4_col2" class="data row4 col2" >postrf</td>
#       <td id="T_519c6_row4_col3" class="data row4 col3" >20.94%</td>
#       <td id="T_519c6_row4_col4" class="data row4 col4" >41.99%</td>
#       <td id="T_519c6_row4_col5" class="data row4 col5" >27.94%</td>
#       <td id="T_519c6_row4_col6" class="data row4 col6" >238.460526</td>
#       <td id="T_519c6_row4_col7" class="data row4 col7" >143.539474</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_519c6_row5_col0" class="data row5 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_519c6_row5_col1" class="data row5 col1" >len400_hop050_th70</td>
#       <td id="T_519c6_row5_col2" class="data row5 col2" >postrf</td>
#       <td id="T_519c6_row5_col3" class="data row5 col3" >19.40%</td>
#       <td id="T_519c6_row5_col4" class="data row5 col4" >28.73%</td>
#       <td id="T_519c6_row5_col5" class="data row5 col5" >23.16%</td>
#       <td id="T_519c6_row5_col6" class="data row5 col6" >251.038462</td>
#       <td id="T_519c6_row5_col7" class="data row5 col7" >224.750000</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row6" class="row_heading level0 row6" >35</th>
#       <td id="T_519c6_row6_col0" class="data row6 col0" >v4_random_nph_1</td>
#       <td id="T_519c6_row6_col1" class="data row6 col1" >len400_hop050_th90</td>
#       <td id="T_519c6_row6_col2" class="data row6 col2" >postrf</td>
#       <td id="T_519c6_row6_col3" class="data row6 col3" >19.13%</td>
#       <td id="T_519c6_row6_col4" class="data row6 col4" >31.49%</td>
#       <td id="T_519c6_row6_col5" class="data row6 col5" >23.80%</td>
#       <td id="T_519c6_row6_col6" class="data row6 col6" >241.421053</td>
#       <td id="T_519c6_row6_col7" class="data row6 col7" >223.807018</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_519c6_row7_col0" class="data row7 col0" >v2_quality_and_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row7_col1" class="data row7 col1" >len400_hop050_th90</td>
#       <td id="T_519c6_row7_col2" class="data row7 col2" >postrf</td>
#       <td id="T_519c6_row7_col3" class="data row7 col3" >18.73%</td>
#       <td id="T_519c6_row7_col4" class="data row7 col4" >30.94%</td>
#       <td id="T_519c6_row7_col5" class="data row7 col5" >23.33%</td>
#       <td id="T_519c6_row7_col6" class="data row7 col6" >238.803571</td>
#       <td id="T_519c6_row7_col7" class="data row7 col7" >238.839286</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_519c6_row8_col0" class="data row8 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row8_col1" class="data row8 col1" >len400_hop050_th60</td>
#       <td id="T_519c6_row8_col2" class="data row8 col2" >postrf</td>
#       <td id="T_519c6_row8_col3" class="data row8 col3" >18.30%</td>
#       <td id="T_519c6_row8_col4" class="data row8 col4" >40.33%</td>
#       <td id="T_519c6_row8_col5" class="data row8 col5" >25.17%</td>
#       <td id="T_519c6_row8_col6" class="data row8 col6" >247.616438</td>
#       <td id="T_519c6_row8_col7" class="data row8 col7" >146.890411</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_519c6_row9_col0" class="data row9 col0" >v3_quality_balanced_nph_1</td>
#       <td id="T_519c6_row9_col1" class="data row9 col1" >len400_hop050_th60</td>
#       <td id="T_519c6_row9_col2" class="data row9 col2" >postrf</td>
#       <td id="T_519c6_row9_col3" class="data row9 col3" >17.53%</td>
#       <td id="T_519c6_row9_col4" class="data row9 col4" >28.18%</td>
#       <td id="T_519c6_row9_col5" class="data row9 col5" >21.61%</td>
#       <td id="T_519c6_row9_col6" class="data row9 col6" >256.333333</td>
#       <td id="T_519c6_row9_col7" class="data row9 col7" >226.490196</td>
#     </tr>
#     <tr>
#       <th id="T_519c6_level0_row10" class="row_heading level0 row10" >4</th>
#       <td id="T_519c6_row10_col0" class="data row10 col0" >v1_clipwise_balanced_nph_1</td>
#       <td id="T_519c6_row10_col1" class="data row10 col1" >len400_hop050_th50</td>
#       <td id="T_519c6_row10_col2" class="data row10 col2" >postrf</td>

# %%
metrics = ["precision", "recall", "f1"]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)
for ax, m in zip(axes, metrics):
    _line_per_model_or_layer(ax, df, y=m, title=m.capitalize(), share_ylim=(0,1))

# Put legend only once, outside the last axis
handles, labels = axes[-1].get_legend_handles_labels()
axes[-1].legend(handles, labels, bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
df_th90 = df[df["threshold"] == 0.9]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
for ax, m in zip(axes, ["precision", "recall", "f1"]):
    _bar_by_model(ax, df_th90, y=m, title=f"{m.capitalize()} at Threshold = 0.9")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_57594/516024296.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
qualities = [("recall_q1", "Recall Q1"), ("recall_q2", "Recall Q2"), ("recall_q3", "Recall Q3"),
             ("f1_q1", "F1 Q1"), ("f1_q2", "F1 Q2"), ("f1_q3", "F1 Q3")]

for col, title in qualities:
    if col in df.columns:
        plt.figure(figsize=(10, 5))
        _line_per_model_or_layer(plt.gca(), df, y=col, title=f"{title} across thresholds", share_ylim=(0,1))
        plt.legend(title="Model • Layer")
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(10, 7))
group_keys = ["model", "layer"] if "layer" in df.columns else ["model"]
for key, g in df.groupby(group_keys):
    label = " • ".join(key) if isinstance(key, tuple) else key
    g = g.sort_values("threshold")
    plt.plot(g["recall"], g["precision"], "-o", label=label)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall across thresholds")
plt.xlim(0, 1); plt.ylim(0, 1)
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
# Best by F1 per (model, layer)
best_f1 = (df.sort_values(["model", "layer", "f1"], ascending=[True, True, False])
             .groupby(["model", "layer"], as_index=False).first())
best_precision = (df.sort_values(["model", "layer", "precision"], ascending=[True, True, False])
                    .groupby(["model", "layer"], as_index=False).first())
best_recall = (df.sort_values(["model", "layer", "recall"], ascending=[True, True, False])
                 .groupby(["model", "layer"], as_index=False).first())

# Display compact tables
best_f1[["model","layer","variant","threshold","precision","recall","f1"]].sort_values("f1", ascending=False).head(20)
# Out:
#                                     model   layer             variant  \
# 0              v1_clipwise_balanced_nph_1  postrf  len400_hop050_th90
# 2               v3_quality_balanced_nph_1  postrf  len400_hop050_th90
# 3                         v4_random_nph_1  postrf  len400_hop050_th90
# 1  v2_quality_and_clipwise_balanced_nph_1  postrf  len400_hop050_th90
#
#    threshold  precision    recall        f1
# 0        0.9   0.325758  0.475138  0.386517
# 2        0.9   0.292035  0.364641  0.324324
# 3        0.9   0.191275  0.314917  0.237996
# 1        0.9   0.187291  0.309392  0.233333

# %%
# Bars for the best F1 per model/layer
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

_bar_by_model(axes[0], best_precision, y="precision", title="Best Precision per Model/Layer")
_bar_by_model(axes[1], best_recall,    y="recall",    title="Best Recall per Model/Layer")
_bar_by_model(axes[2], best_f1,        y="f1",        title="Best F1 per Model/Layer")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_57594/3551076614.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
if "layer" in df.columns:
    layers = natsorted(df["layer"].unique().tolist())
    metrics = ["precision", "recall", "f1"]
    fig, axes = plt.subplots(len(metrics), len(layers), figsize=(6*len(layers), 4*len(metrics)), sharex=True, sharey=True)
    if axes.ndim == 1:
        axes = axes[:, None]
    for i, m in enumerate(metrics):
        for j, layer in enumerate(layers):
            ax = axes[i, j]
            _line_per_model_or_layer(ax, df[df["layer"] == layer], y=m, title=f"{m.capitalize()} • {layer}", share_ylim=(0,1))
            if i == 0:
                ax.legend(title="Model", bbox_to_anchor=(1.05,1), loc="upper left")
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/yy/mfzpfh1n7vsdd7qnk0wl69700000gn/T/ipykernel_57594/3311031867.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
